# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import re
import tensorflow as tf
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from urllib.parse import urlparse
from sklearn import preprocessing
import tldextract
# %matplotlib inline
import random
import gc
import os
import random
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import LSTM, Dense, Dropout, Embedding
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SpatialDropout1D
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.callbacks import ReduceLROnPlateau

# %%
df=pd.read_csv("/content/mal_1.csv")
df2=pd.read_csv("/content/mal_2.csv")
df3=pd.read_csv("/content/mal_3.csv")

# %%
df['type']=df['type'].replace({'phishing':1,'benign':0,'defacement':1,'malware':1})

# %%
df2.drop(df2.columns[df2.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
df2.drop('label',axis = 1, inplace = True)
df2=df2.rename(columns={'result': 'type'})

# %%
df3=df3.rename(columns={'label': 'type'})
df3['type']=df3['type'].replace({'bad':1,'good':0})

# %%
df=df.append(df2)
df=df.append(df3)

# %%
df.drop_duplicates(keep='first',inplace=True)

# %%
sns.countplot(x='type',data=df, palette='rainbow')
plt.show()

# %%
#Feature Extraction methods

#returns the length of the url
def http(s):
    return s.count('http')

#returns the count of http in the url
def https(s):
    return s.count('https')

#returns the count of www in the url
def www(s):
    return s.count('www')

#returns the count of digits in the url
def digit(s):
    return sum(i.isnumeric() for i in s)

#returns the count of alphabets in the url
def alpha(s):
    return sum(i.isalpha() for i in s)

#returns the count of special character's in the url
def spec_char(s):
    return sum((not(i.isalpha()) and not(i.isnumeric())) for i in s)

#returns the count of / in the url
def spec_char_1(s):
    return s.count('/')

#returns the count of ! in the url
def spec_char_2(s):
    return s.count('!')

#returns the count of . in the url
def spec_char_3(s):
    return s.count('.')

#returns the count of @ in the url    
def spec_char_4(s):
    return s.count('@')

#returns the count of % in the url
def spec_char_5(s):
    return s.count('%')

#returns the count of ? in the url
def spec_char_6(s):
    return s.count('?')

#returns the count of = in the url
def spec_char_7(s):
    return s.count('=')

#returns the count of + in the url
def spec_char_8(s):
    return s.count('+')

#returns the count of - in the url
def spec_char_9(s):
    return s.count('-')

#returns the count of & in the url
def spec_char_10(s):
    return s.count('&')

def query_length(s):
    return len(urlparse(s).query)

#returns the domain of the url
def dom_suffix(s):
    domains={'com':1,'edu':2,'org':3,'net':4,'onion':5,'in':6}
    s=tldextract.extract(s).suffix
    if s in domains.keys():
        return domains[s]
    else:
        return 0

#returns the length of the domain
def dom_length(s):
    return len(tldextract.extract(s).domain)


#returns the length of the sub_domain
def subdom_length(s):
    return len(tldextract.extract(s).subdomain)

#returns the length of the url path
def path_length(s):
    return len(urlparse(s).path)

#returns 1 if url contains a query
def has_query(s):
    if len(urlparse(s).query)==0:
        return 0
    else:
        return 1
#Checks for ipv4 in the url
def ip(s):
    has_ip=re.search('(([01]?\\d\\d?|2[0-4]\\d|25[0-5])\\.([01]?\\d\\d?|2[0-4]\\d|25[0-5])\\.([01]?\\d\\d?|2[0-4]\\d|25[0-5])\\.'
    '([01]?\\d\\d?|2[0-4]\\d|25[0-5])\\/)|'  # IPv4
    '((0x[0-9a-fA-F]{1,2})\\.(0x[0-9a-fA-F]{1,2})\\.(0x[0-9a-fA-F]{1,2})\\.(0x[0-9a-fA-F]{1,2})\\/)' # IPv4 in hexadecimal
    '(?:[a-fA-F0-9]{1,4}:){7}[a-fA-F0-9]{1,4}', s)
    if has_ip:
        return 1
    else:
        return 0
        
#.php .EXE .html .htm .txt .avi .jar .js
def extension(s):
    #domains={'.htm':1,'.html':2,'.js':3,'.css':4,'.exe':5,}
    if '.htm' in s:
        return 1
    elif '.html' in s:
        return 2
    elif '.js' in s:
        return 3
    elif '.css' in s:
        return 4
    elif '.exe' in s:
        return 5
    elif '.php' in s:
        return 6
    elif '.py' in s:
        return 7
    else:
        return 0

# %%
#Extracting the feautures

df['len']=df['url'].apply(lambda s : len(str(s)))

df['http_count']=df['url'].apply(lambda s : http(s))

df['https_count']=df['url'].apply(lambda s : https(s))

df['www']=df['url'].apply(lambda s : www(s))

df['digit_count']=df['url'].apply(lambda s: digit(s))

df['alpha_count']=df['url'].apply(lambda s: alpha(s))

df['spec_char_count']=df['url'].apply(lambda s: spec_char(s))

df['/']=df['url'].apply(lambda s: spec_char_1(s))

df['!']=df['url'].apply(lambda s: spec_char_2(s))

df['.']=df['url'].apply(lambda s: spec_char_3(s))

df['@']=df['url'].apply(lambda s: spec_char_4(s))

df['%']=df['url'].apply(lambda s: spec_char_5(s))

df['?']=df['url'].apply(lambda s: spec_char_6(s))

df['=']=df['url'].apply(lambda s: spec_char_7(s))

df['+']=df['url'].apply(lambda s: spec_char_8(s))

df['-']=df['url'].apply(lambda s: spec_char_9(s))

df['dom_suffix']=df['url'].apply(lambda s: dom_suffix(s))

df['dom_length']=df['url'].apply(lambda s: dom_length(s))

df['subdom_length']=df['url'].apply(lambda s: subdom_length(s))

df['query']=df['url'].apply(lambda s: has_query(s))

df['extension']=df['url'].apply(lambda s: extension(s))

df['ip']=df['url'].apply(lambda s: ip(s))

df.drop('url',axis = 1, inplace = True)

# %%
df = shuffle(df)

# %%
df.head()
# Out:
#         type  len  http_count  https_count  ...  subdom_length  query  extension  ip
# 462598     0   21           0            0  ...              7      0          0   0
# 406800     0   24           0            0  ...              0      0          0   0
# 22805      1   36           0            0  ...              0      0          0   0
# 319983     0   85           0            0  ...              2      0          0   0
# 139693     0   70           1            1  ...              3      0          0   0
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1156638 entries, 462598 to 207152
# Data columns (total 23 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   type             1156638 non-null  int64
#  1   len              1156638 non-null  int64
#  2   http_count       1156638 non-null  int64
#  3   https_count      1156638 non-null  int64
#  4   www              1156638 non-null  int64
#  5   digit_count      1156638 non-null  int64
#  6   alpha_count      1156638 non-null  int64
#  7   spec_char_count  1156638 non-null  int64
#  8   /                1156638 non-null  int64
#  9   !                1156638 non-null  int64
#  10  .                1156638 non-null  int64
#  11  @                1156638 non-null  int64
#  12  %                1156638 non-null  int64
#  13  ?                1156638 non-null  int64
#  14  =                1156638 non-null  int64
#  15  +                1156638 non-null  int64
#  16  -                1156638 non-null  int64
#  17  dom_suffix       1156638 non-null  int64
#  18  dom_length       1156638 non-null  int64
#  19  subdom_length    1156638 non-null  int64
#  20  query            1156638 non-null  int64
#  21  extension        1156638 non-null  int64
#  22  ip               1156638 non-null  int64
# dtypes: int64(23)
# memory usage: 211.8 MB

# %%
x=['len','http_count','https_count','www','digit_count','alpha_count','spec_char_count','/','!','.','@','%','?','=','+','-','dom_suffix','dom_length','subdom_length','query','extension','ip']
min_max_scaler = preprocessing.MinMaxScaler()
column_names_to_normalize = x
x = df[column_names_to_normalize].values
x_scaled = min_max_scaler.fit_transform(x)
df_temp = pd.DataFrame(x_scaled, columns=column_names_to_normalize, index = df.index)
df[column_names_to_normalize] = df_temp

# %%
x=df[['len','http_count','https_count','www','digit_count','alpha_count','spec_char_count','/','!','.','@','%','?','=','+','-','dom_suffix','dom_length','subdom_length','query','extension','ip']]
y=df['type']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,shuffle='True')

# %%
#Callbacks
es = EarlyStopping(monitor='val_loss', 
        mode='min', 
        patience=3,
        restore_best_weights=True, 
        verbose=1)
mc = ModelCheckpoint('best_model.h5',verbose=1,save_best_only=True, save_weights_only = True)
reduce_lr=ReduceLROnPlateau( monitor="val_loss",factor=0.5,patience=1, verbose=1)

# %%
#Model Builder Function
def create_nn(layers,activation):
  nn=Sequential()
  nn.add(keras.Input(shape=(22,)))
  for i,nodes in enumerate(layers):
      nn.add(Dense(nodes,activation=activation))
  nn.add(Dense(1, activation='sigmoid'))
  nn.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
  return nn
nn=KerasClassifier(build_fn=create_nn,verbose=1)

# %%
nn

# %%
layers=[[5,10,15,20],[5,10,15,20],[5,10,15,20],[5,10,15,20]]
activations=['sigmoid','relu']
param_grid=dict(layers=layers,activation=activations,batch_size=[128,256],epochs=[100])
grid=GridSearchCV(estimator=nn,param_grid=param_grid)

# %%
best_model=grid.fit(x_train,y_train,validation_data=(x_test, y_test),callbacks=[es,mc,reduce_lr])
# Out:
# Epoch 1/100
# 5784/5784 [==============================] - 27s 4ms/step - loss: 0.4126 - accuracy: 0.8196 - val_loss: 0.3348 - val_accuracy: 0.8724
#
# Epoch 00001: val_loss did not improve from 0.32299
# Epoch 2/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.3253 - accuracy: 0.8744 - val_loss: 0.3237 - val_accuracy: 0.8761
#
# Epoch 00002: val_loss did not improve from 0.32299
# Epoch 3/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.3190 - accuracy: 0.8775 - val_loss: 0.3177 - val_accuracy: 0.8763
#
# Epoch 00003: val_loss improved from 0.32299 to 0.31773, saving model to best_model.h5
# Epoch 4/100
# 5784/5784 [==============================] - 25s 4ms/step - loss: 0.3108 - accuracy: 0.8760 - val_loss: 0.3049 - val_accuracy: 0.8717
#
# Epoch 00004: val_loss improved from 0.31773 to 0.30485, saving model to best_model.h5
# Epoch 5/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2973 - accuracy: 0.8720 - val_loss: 0.2934 - val_accuracy: 0.8735
#
# Epoch 00005: val_loss improved from 0.30485 to 0.29342, saving model to best_model.h5
# Epoch 6/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2837 - accuracy: 0.8827 - val_loss: 0.2754 - val_accuracy: 0.8883
#
# Epoch 00006: val_loss improved from 0.29342 to 0.27540, saving model to best_model.h5
# Epoch 7/100
# 5784/5784 [==============================] - 25s 4ms/step - loss: 0.2666 - accuracy: 0.8933 - val_loss: 0.2616 - val_accuracy: 0.8949
#
# Epoch 00007: val_loss improved from 0.27540 to 0.26165, saving model to best_model.h5
# Epoch 8/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2574 - accuracy: 0.8961 - val_loss: 0.2548 - val_accuracy: 0.8962
#
# Epoch 00008: val_loss improved from 0.26165 to 0.25481, saving model to best_model.h5
# Epoch 9/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2528 - accuracy: 0.8974 - val_loss: 0.2507 - val_accuracy: 0.8973
#
# Epoch 00009: val_loss improved from 0.25481 to 0.25072, saving model to best_model.h5
# Epoch 10/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2490 - accuracy: 0.8984 - val_loss: 0.2480 - val_accuracy: 0.8987
#
# Epoch 00010: val_loss improved from 0.25072 to 0.24796, saving model to best_model.h5
# Epoch 11/100
# 5784/5784 [==============================] - 25s 4ms/step - loss: 0.2459 - accuracy: 0.8993 - val_loss: 0.2438 - val_accuracy: 0.8986
#
# Epoch 00011: val_loss improved from 0.24796 to 0.24384, saving model to best_model.h5
# Epoch 12/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2432 - accuracy: 0.8998 - val_loss: 0.2443 - val_accuracy: 0.8987
#
# Epoch 00012: val_loss did not improve from 0.24384
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 13/100
# 5784/5784 [==============================] - 25s 4ms/step - loss: 0.2409 - accuracy: 0.9006 - val_loss: 0.2407 - val_accuracy: 0.8998
#
# Epoch 00013: val_loss improved from 0.24384 to 0.24069, saving model to best_model.h5
# Epoch 14/100
# 5784/5784 [==============================] - 25s 4ms/step - loss: 0.2398 - accuracy: 0.9008 - val_loss: 0.2393 - val_accuracy: 0.9003
#
# Epoch 00014: val_loss improved from 0.24069 to 0.23927, saving model to best_model.h5
# Epoch 15/100
# 5784/5784 [==============================] - 25s 4ms/step - loss: 0.2388 - accuracy: 0.9010 - val_loss: 0.2387 - val_accuracy: 0.9004
#
# Epoch 00015: val_loss improved from 0.23927 to 0.23872, saving model to best_model.h5
# Epoch 16/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.2378 - accuracy: 0.9013 - val_loss: 0.2376 - val_accuracy: 0.9010
#
# Epoch 00016: val_loss improved from 0.23872 to 0.23755, saving model to best_model.h5
# Epoch 17/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2368 - accuracy: 0.9016 - val_loss: 0.2360 - val_accuracy: 0.9015
#
# Epoch 00017: val_loss improved from 0.23755 to 0.23598, saving model to best_model.h5
# Epoch 18/100
# 5784/5784 [==============================] - 25s 4ms/step - loss: 0.2359 - accuracy: 0.9017 - val_loss: 0.2376 - val_accuracy: 0.9007
#
# Epoch 00018: val_loss did not improve from 0.23598
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 19/100
# 5784/5784 [==============================] - 25s 4ms/step - loss: 0.2349 - accuracy: 0.9021 - val_loss: 0.2347 - val_accuracy: 0.9017
#
# Epoch 00019: val_loss improved from 0.23598 to 0.23469, saving model to best_model.h5
# Epoch 20/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2345 - accuracy: 0.9022 - val_loss: 0.2343 - val_accuracy: 0.9018
#
# Epoch 00020: val_loss improved from 0.23469 to 0.23430, saving model to best_model.h5
# Epoch 21/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.2341 - accuracy: 0.9022 - val_loss: 0.2341 - val_accuracy: 0.9014
#
# Epoch 00021: val_loss improved from 0.23430 to 0.23414, saving model to best_model.h5
# Epoch 22/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2337 - accuracy: 0.9024 - val_loss: 0.2336 - val_accuracy: 0.9021
#
# Epoch 00022: val_loss improved from 0.23414 to 0.23359, saving model to best_model.h5
# Epoch 23/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.2334 - accuracy: 0.9024 - val_loss: 0.2331 - val_accuracy: 0.9020
#
# Epoch 00023: val_loss improved from 0.23359 to 0.23311, saving model to best_model.h5
# Epoch 24/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2330 - accuracy: 0.9026 - val_loss: 0.2333 - val_accuracy: 0.9017
#
# Epoch 00024: val_loss did not improve from 0.23311
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 25/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2326 - accuracy: 0.9026 - val_loss: 0.2329 - val_accuracy: 0.9025
#
# Epoch 00025: val_loss improved from 0.23311 to 0.23285, saving model to best_model.h5
# Epoch 26/100
# 5784/5784 [==============================] - 25s 4ms/step - loss: 0.2325 - accuracy: 0.9028 - val_loss: 0.2325 - val_accuracy: 0.9022
#
# Epoch 00026: val_loss improved from 0.23285 to 0.23248, saving model to best_model.h5
# Epoch 27/100
# 5784/5784 [==============================] - 25s 4ms/step - loss: 0.2323 - accuracy: 0.9026 - val_loss: 0.2323 - val_accuracy: 0.9021
#
# Epoch 00027: val_loss improved from 0.23248 to 0.23230, saving model to best_model.h5
# Epoch 28/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2321 - accuracy: 0.9027 - val_loss: 0.2321 - val_accuracy: 0.9023
#
# Epoch 00028: val_loss improved from 0.23230 to 0.23215, saving model to best_model.h5
# Epoch 29/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2319 - accuracy: 0.9029 - val_loss: 0.2320 - val_accuracy: 0.9023
#
# Epoch 00029: val_loss improved from 0.23215 to 0.23197, saving model to best_model.h5
# Epoch 30/100
# 5784/5784 [==============================] - 25s 4ms/step - loss: 0.2318 - accuracy: 0.9028 - val_loss: 0.2318 - val_accuracy: 0.9024
#
# Epoch 00030: val_loss improved from 0.23197 to 0.23184, saving model to best_model.h5
# Epoch 31/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.2316 - accuracy: 0.9028 - val_loss: 0.2318 - val_accuracy: 0.9023
#
# Epoch 00031: val_loss improved from 0.23184 to 0.23179, saving model to best_model.h5
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 32/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2315 - accuracy: 0.9030 - val_loss: 0.2316 - val_accuracy: 0.9024
#
# Epoch 00032: val_loss improved from 0.23179 to 0.23160, saving model to best_model.h5
# Epoch 33/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.2314 - accuracy: 0.9029 - val_loss: 0.2315 - val_accuracy: 0.9024
#
# Epoch 00033: val_loss improved from 0.23160 to 0.23153, saving model to best_model.h5
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 34/100
# 5784/5784 [==============================] - 25s 4ms/step - loss: 0.2313 - accuracy: 0.9031 - val_loss: 0.2315 - val_accuracy: 0.9025
#
# Epoch 00034: val_loss improved from 0.23153 to 0.23149, saving model to best_model.h5
# Epoch 35/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2312 - accuracy: 0.9030 - val_loss: 0.2315 - val_accuracy: 0.9024
#
# Epoch 00035: val_loss did not improve from 0.23149
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 36/100
# 5784/5784 [==============================] - 25s 4ms/step - loss: 0.2312 - accuracy: 0.9030 - val_loss: 0.2315 - val_accuracy: 0.9025
#
# Epoch 00036: val_loss improved from 0.23149 to 0.23147, saving model to best_model.h5
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 37/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2312 - accuracy: 0.9030 - val_loss: 0.2314 - val_accuracy: 0.9024
#
# Epoch 00037: val_loss improved from 0.23147 to 0.23144, saving model to best_model.h5
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 38/100
# 5784/5784 [==============================] - 25s 4ms/step - loss: 0.2312 - accuracy: 0.9030 - val_loss: 0.2314 - val_accuracy: 0.9024
#
# Epoch 00038: val_loss improved from 0.23144 to 0.23142, saving model to best_model.h5
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 39/100
# 5784/5784 [==============================] - 24s 4ms/step - loss: 0.2311 - accuracy: 0.9029 - val_loss: 0.2314 - val_accuracy: 0.9024
#
# Epoch 00039: val_loss improved from 0.23142 to 0.23142, saving model to best_model.h5
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 40/100
# 5784/5784 [==============================] - 25s 4ms/step - loss: 0.2311 - accuracy: 0.9030 - val_loss: 0.2314 - val_accuracy: 0.9024
#
# Epoch 00040: val_loss improved from 0.23142 to 0.23142, saving model to best_model.h5
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 41/100
# 5784/5784 [==============================] - 24s 4ms/step - loss: 0.2311 - accuracy: 0.9030 - val_loss: 0.2314 - val_accuracy: 0.9024
#
# Epoch 00041: val_loss improved from 0.23142 to 0.23142, saving model to best_model.h5
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 42/100
# 5784/5784 [==============================] - 24s 4ms/step - loss: 0.2311 - accuracy: 0.9030 - val_loss: 0.2314 - val_accuracy: 0.9024
#
# Epoch 00042: val_loss improved from 0.23142 to 0.23142, saving model to best_model.h5
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 43/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2311 - accuracy: 0.9030 - val_loss: 0.2314 - val_accuracy: 0.9024
#
# Epoch 00043: val_loss improved from 0.23142 to 0.23142, saving model to best_model.h5
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 44/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2311 - accuracy: 0.9029 - val_loss: 0.2314 - val_accuracy: 0.9024
#
# Epoch 00044: val_loss improved from 0.23142 to 0.23142, saving model to best_model.h5
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 45/100
# 5784/5784 [==============================] - 25s 4ms/step - loss: 0.2311 - accuracy: 0.9029 - val_loss: 0.2314 - val_accuracy: 0.9024
#
# Epoch 00045: val_loss did not improve from 0.23142
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 46/100
# 5784/5784 [==============================] - 25s 4ms/step - loss: 0.2311 - accuracy: 0.9029 - val_loss: 0.2314 - val_accuracy: 0.9024
#
# Epoch 00046: val_loss did not improve from 0.23142
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 47/100
# 5784/5784 [==============================] - 25s 4ms/step - loss: 0.2311 - accuracy: 0.9029 - val_loss: 0.2314 - val_accuracy: 0.9024
# Restoring model weights from the end of the best epoch.
#
# Epoch 00047: val_loss did not improve from 0.23142
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# Epoch 00047: early stopping
# 1446/1446 [==============================] - 4s 3ms/step - loss: 0.2302 - accuracy: 0.9026
# Epoch 1/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.4174 - accuracy: 0.8175 - val_loss: 0.3343 - val_accuracy: 0.8677
#
# Epoch 00001: val_loss did not improve from 0.23142
# Epoch 2/100
# 5784/5784 [==============================] - 25s 4ms/step - loss: 0.3269 - accuracy: 0.8737 - val_loss: 0.3256 - val_accuracy: 0.8733
#
# Epoch 00002: val_loss did not improve from 0.23142
# Epoch 3/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.3223 - accuracy: 0.8763 - val_loss: 0.3234 - val_accuracy: 0.8749
#
# Epoch 00003: val_loss did not improve from 0.23142
# Epoch 4/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.3207 - accuracy: 0.8783 - val_loss: 0.3231 - val_accuracy: 0.8737
#
# Epoch 00004: val_loss did not improve from 0.23142
# Epoch 5/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.3175 - accuracy: 0.8783 - val_loss: 0.3151 - val_accuracy: 0.8746
#
# Epoch 00005: val_loss did not improve from 0.23142
# Epoch 6/100
# 5784/5784 [==============================] - 31s 5ms/step - loss: 0.3058 - accuracy: 0.8736 - val_loss: 0.3005 - val_accuracy: 0.8712
#
# Epoch 00006: val_loss did not improve from 0.23142
# Epoch 7/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2932 - accuracy: 0.8738 - val_loss: 0.2888 - val_accuracy: 0.8812
#
# Epoch 00007: val_loss did not improve from 0.23142
# Epoch 8/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2786 - accuracy: 0.8870 - val_loss: 0.2728 - val_accuracy: 0.8916
#
# Epoch 00008: val_loss did not improve from 0.23142
# Epoch 9/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2685 - accuracy: 0.8940 - val_loss: 0.2661 - val_accuracy: 0.8932
#
# Epoch 00009: val_loss did not improve from 0.23142
# Epoch 10/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2629 - accuracy: 0.8959 - val_loss: 0.2604 - val_accuracy: 0.8942
#
# Epoch 00010: val_loss did not improve from 0.23142
# Epoch 11/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2579 - accuracy: 0.8972 - val_loss: 0.2564 - val_accuracy: 0.9016
#
# Epoch 00011: val_loss did not improve from 0.23142
# Epoch 12/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.2537 - accuracy: 0.8981 - val_loss: 0.2530 - val_accuracy: 0.9022
#
# Epoch 00012: val_loss did not improve from 0.23142
# Epoch 13/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.2503 - accuracy: 0.8986 - val_loss: 0.2489 - val_accuracy: 0.8991
#
# Epoch 00013: val_loss did not improve from 0.23142
# Epoch 14/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.2475 - accuracy: 0.8987 - val_loss: 0.2456 - val_accuracy: 0.8985
#
# Epoch 00014: val_loss did not improve from 0.23142
# Epoch 15/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2448 - accuracy: 0.8990 - val_loss: 0.2429 - val_accuracy: 0.8976
#
# Epoch 00015: val_loss did not improve from 0.23142
# Epoch 16/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2423 - accuracy: 0.8995 - val_loss: 0.2413 - val_accuracy: 0.8977
#
# Epoch 00016: val_loss did not improve from 0.23142
# Epoch 17/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2396 - accuracy: 0.9000 - val_loss: 0.2401 - val_accuracy: 0.9017
#
# Epoch 00017: val_loss did not improve from 0.23142
# Epoch 18/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2362 - accuracy: 0.9013 - val_loss: 0.2353 - val_accuracy: 0.9006
#
# Epoch 00018: val_loss did not improve from 0.23142
# Epoch 19/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2340 - accuracy: 0.9022 - val_loss: 0.2339 - val_accuracy: 0.9023
#
# Epoch 00019: val_loss did not improve from 0.23142
# Epoch 20/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2325 - accuracy: 0.9026 - val_loss: 0.2312 - val_accuracy: 0.9022
#
# Epoch 00020: val_loss improved from 0.23142 to 0.23116, saving model to best_model.h5
# Epoch 21/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2311 - accuracy: 0.9030 - val_loss: 0.2297 - val_accuracy: 0.9025
#
# Epoch 00021: val_loss improved from 0.23116 to 0.22975, saving model to best_model.h5
# Epoch 22/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2299 - accuracy: 0.9034 - val_loss: 0.2315 - val_accuracy: 0.9027
#
# Epoch 00022: val_loss did not improve from 0.22975
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 23/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.2285 - accuracy: 0.9037 - val_loss: 0.2284 - val_accuracy: 0.9025
#
# Epoch 00023: val_loss improved from 0.22975 to 0.22836, saving model to best_model.h5
# Epoch 24/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2280 - accuracy: 0.9037 - val_loss: 0.2278 - val_accuracy: 0.9032
#
# Epoch 00024: val_loss improved from 0.22836 to 0.22779, saving model to best_model.h5
# Epoch 25/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2276 - accuracy: 0.9039 - val_loss: 0.2273 - val_accuracy: 0.9032
#
# Epoch 00025: val_loss improved from 0.22779 to 0.22729, saving model to best_model.h5
# Epoch 26/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2271 - accuracy: 0.9041 - val_loss: 0.2272 - val_accuracy: 0.9030
#
# Epoch 00026: val_loss improved from 0.22729 to 0.22718, saving model to best_model.h5
# Epoch 27/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2267 - accuracy: 0.9042 - val_loss: 0.2269 - val_accuracy: 0.9035
#
# Epoch 00027: val_loss improved from 0.22718 to 0.22687, saving model to best_model.h5
# Epoch 28/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.2264 - accuracy: 0.9043 - val_loss: 0.2263 - val_accuracy: 0.9034
#
# Epoch 00028: val_loss improved from 0.22687 to 0.22631, saving model to best_model.h5
# Epoch 29/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2259 - accuracy: 0.9043 - val_loss: 0.2257 - val_accuracy: 0.9037
#
# Epoch 00029: val_loss improved from 0.22631 to 0.22573, saving model to best_model.h5
# Epoch 30/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2257 - accuracy: 0.9043 - val_loss: 0.2262 - val_accuracy: 0.9041
#
# Epoch 00030: val_loss did not improve from 0.22573
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 31/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.2251 - accuracy: 0.9045 - val_loss: 0.2256 - val_accuracy: 0.9035
#
# Epoch 00031: val_loss improved from 0.22573 to 0.22560, saving model to best_model.h5
# Epoch 32/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2249 - accuracy: 0.9047 - val_loss: 0.2255 - val_accuracy: 0.9041
#
# Epoch 00032: val_loss improved from 0.22560 to 0.22554, saving model to best_model.h5
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 33/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2246 - accuracy: 0.9045 - val_loss: 0.2249 - val_accuracy: 0.9039
#
# Epoch 00033: val_loss improved from 0.22554 to 0.22487, saving model to best_model.h5
# Epoch 34/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.2245 - accuracy: 0.9046 - val_loss: 0.2250 - val_accuracy: 0.9040
#
# Epoch 00034: val_loss did not improve from 0.22487
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 35/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.2244 - accuracy: 0.9047 - val_loss: 0.2249 - val_accuracy: 0.9040
#
# Epoch 00035: val_loss did not improve from 0.22487
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 36/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2243 - accuracy: 0.9047 - val_loss: 0.2247 - val_accuracy: 0.9041
#
# Epoch 00036: val_loss improved from 0.22487 to 0.22472, saving model to best_model.h5
# Epoch 37/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.2243 - accuracy: 0.9047 - val_loss: 0.2248 - val_accuracy: 0.9038
#
# Epoch 00037: val_loss did not improve from 0.22472
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 38/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2243 - accuracy: 0.9047 - val_loss: 0.2247 - val_accuracy: 0.9040
#
# Epoch 00038: val_loss improved from 0.22472 to 0.22469, saving model to best_model.h5
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 39/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2242 - accuracy: 0.9047 - val_loss: 0.2247 - val_accuracy: 0.9040
#
# Epoch 00039: val_loss improved from 0.22469 to 0.22468, saving model to best_model.h5
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 40/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.2242 - accuracy: 0.9047 - val_loss: 0.2247 - val_accuracy: 0.9040
#
# Epoch 00040: val_loss improved from 0.22468 to 0.22468, saving model to best_model.h5
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 41/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2242 - accuracy: 0.9047 - val_loss: 0.2247 - val_accuracy: 0.9040
#
# Epoch 00041: val_loss did not improve from 0.22468
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 42/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2242 - accuracy: 0.9047 - val_loss: 0.2247 - val_accuracy: 0.9040
#
# Epoch 00042: val_loss improved from 0.22468 to 0.22468, saving model to best_model.h5
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 43/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2242 - accuracy: 0.9047 - val_loss: 0.2247 - val_accuracy: 0.9040
#
# Epoch 00043: val_loss improved from 0.22468 to 0.22468, saving model to best_model.h5
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 44/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2242 - accuracy: 0.9047 - val_loss: 0.2247 - val_accuracy: 0.9040
#
# Epoch 00044: val_loss improved from 0.22468 to 0.22468, saving model to best_model.h5
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 45/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2242 - accuracy: 0.9047 - val_loss: 0.2247 - val_accuracy: 0.9040
#
# Epoch 00045: val_loss did not improve from 0.22468
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 46/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2242 - accuracy: 0.9047 - val_loss: 0.2247 - val_accuracy: 0.9040
#
# Epoch 00046: val_loss did not improve from 0.22468
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 47/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2242 - accuracy: 0.9047 - val_loss: 0.2247 - val_accuracy: 0.9040
# Restoring model weights from the end of the best epoch.
#
# Epoch 00047: val_loss did not improve from 0.22468
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 00047: early stopping
# 1446/1446 [==============================] - 4s 3ms/step - loss: 0.2247 - accuracy: 0.9045
# Epoch 1/100
# 5784/5784 [==============================] - 27s 4ms/step - loss: 0.4073 - accuracy: 0.8231 - val_loss: 0.3323 - val_accuracy: 0.8705
#
# Epoch 00001: val_loss did not improve from 0.22468
# Epoch 2/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.3258 - accuracy: 0.8739 - val_loss: 0.3246 - val_accuracy: 0.8748
#
# Epoch 00002: val_loss did not improve from 0.22468
# Epoch 3/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.3203 - accuracy: 0.8773 - val_loss: 0.3204 - val_accuracy: 0.8782
#
# Epoch 00003: val_loss did not improve from 0.22468
# Epoch 4/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.3160 - accuracy: 0.8804 - val_loss: 0.3150 - val_accuracy: 0.8788
#
# Epoch 00004: val_loss did not improve from 0.22468
# Epoch 5/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.3107 - accuracy: 0.8806 - val_loss: 0.3087 - val_accuracy: 0.8742
#
# Epoch 00005: val_loss did not improve from 0.22468
# Epoch 6/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.3017 - accuracy: 0.8768 - val_loss: 0.2976 - val_accuracy: 0.8760
#
# Epoch 00006: val_loss did not improve from 0.22468
# Epoch 7/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2866 - accuracy: 0.8753 - val_loss: 0.2779 - val_accuracy: 0.8845
#
# Epoch 00007: val_loss did not improve from 0.22468
# Epoch 8/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2677 - accuracy: 0.8906 - val_loss: 0.2601 - val_accuracy: 0.8930
#
# Epoch 00008: val_loss did not improve from 0.22468
# Epoch 9/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2554 - accuracy: 0.8972 - val_loss: 0.2527 - val_accuracy: 0.8964
#
# Epoch 00009: val_loss did not improve from 0.22468
# Epoch 10/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2493 - accuracy: 0.8987 - val_loss: 0.2470 - val_accuracy: 0.8984
#
# Epoch 00010: val_loss did not improve from 0.22468
# Epoch 11/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2455 - accuracy: 0.8997 - val_loss: 0.2435 - val_accuracy: 0.8995
#
# Epoch 00011: val_loss did not improve from 0.22468
# Epoch 12/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.2428 - accuracy: 0.9005 - val_loss: 0.2414 - val_accuracy: 0.8997
#
# Epoch 00012: val_loss did not improve from 0.22468
# Epoch 13/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2405 - accuracy: 0.9015 - val_loss: 0.2417 - val_accuracy: 0.9022
#
# Epoch 00013: val_loss did not improve from 0.22468
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 14/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2379 - accuracy: 0.9022 - val_loss: 0.2396 - val_accuracy: 0.9015
#
# Epoch 00014: val_loss did not improve from 0.22468
# Epoch 15/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2367 - accuracy: 0.9031 - val_loss: 0.2376 - val_accuracy: 0.9022
#
# Epoch 00015: val_loss did not improve from 0.22468
# Epoch 16/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2358 - accuracy: 0.9038 - val_loss: 0.2355 - val_accuracy: 0.9032
#
# Epoch 00016: val_loss did not improve from 0.22468
# Epoch 17/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2348 - accuracy: 0.9043 - val_loss: 0.2344 - val_accuracy: 0.9031
#
# Epoch 00017: val_loss did not improve from 0.22468
# Epoch 18/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2341 - accuracy: 0.9043 - val_loss: 0.2336 - val_accuracy: 0.9041
#
# Epoch 00018: val_loss did not improve from 0.22468
# Epoch 19/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2335 - accuracy: 0.9043 - val_loss: 0.2330 - val_accuracy: 0.9035
#
# Epoch 00019: val_loss did not improve from 0.22468
# Epoch 20/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.2329 - accuracy: 0.9045 - val_loss: 0.2345 - val_accuracy: 0.9038
#
# Epoch 00020: val_loss did not improve from 0.22468
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 21/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2321 - accuracy: 0.9046 - val_loss: 0.2331 - val_accuracy: 0.9037
#
# Epoch 00021: val_loss did not improve from 0.22468
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 22/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2318 - accuracy: 0.9045 - val_loss: 0.2320 - val_accuracy: 0.9043
#
# Epoch 00022: val_loss did not improve from 0.22468
# Epoch 23/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2317 - accuracy: 0.9046 - val_loss: 0.2320 - val_accuracy: 0.9042
#
# Epoch 00023: val_loss did not improve from 0.22468
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 24/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2315 - accuracy: 0.9046 - val_loss: 0.2318 - val_accuracy: 0.9041
#
# Epoch 00024: val_loss did not improve from 0.22468
# Epoch 25/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2314 - accuracy: 0.9045 - val_loss: 0.2318 - val_accuracy: 0.9043
#
# Epoch 00025: val_loss did not improve from 0.22468
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 26/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2313 - accuracy: 0.9046 - val_loss: 0.2317 - val_accuracy: 0.9041
#
# Epoch 00026: val_loss did not improve from 0.22468
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 27/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2313 - accuracy: 0.9045 - val_loss: 0.2317 - val_accuracy: 0.9042
#
# Epoch 00027: val_loss did not improve from 0.22468
# Epoch 28/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2313 - accuracy: 0.9045 - val_loss: 0.2317 - val_accuracy: 0.9040
#
# Epoch 00028: val_loss did not improve from 0.22468
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 29/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2313 - accuracy: 0.9045 - val_loss: 0.2317 - val_accuracy: 0.9042
#
# Epoch 00029: val_loss did not improve from 0.22468
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 30/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2312 - accuracy: 0.9045 - val_loss: 0.2317 - val_accuracy: 0.9042
#
# Epoch 00030: val_loss did not improve from 0.22468
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 31/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.2312 - accuracy: 0.9045 - val_loss: 0.2317 - val_accuracy: 0.9041
#
# Epoch 00031: val_loss did not improve from 0.22468
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 32/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2312 - accuracy: 0.9045 - val_loss: 0.2317 - val_accuracy: 0.9041
#
# Epoch 00032: val_loss did not improve from 0.22468
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 33/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2312 - accuracy: 0.9045 - val_loss: 0.2317 - val_accuracy: 0.9041
#
# Epoch 00033: val_loss did not improve from 0.22468
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 34/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2312 - accuracy: 0.9045 - val_loss: 0.2317 - val_accuracy: 0.9041
#
# Epoch 00034: val_loss did not improve from 0.22468
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 35/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2312 - accuracy: 0.9045 - val_loss: 0.2317 - val_accuracy: 0.9041
#
# Epoch 00035: val_loss did not improve from 0.22468
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 36/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.2312 - accuracy: 0.9045 - val_loss: 0.2317 - val_accuracy: 0.9041
#
# Epoch 00036: val_loss did not improve from 0.22468
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 37/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2312 - accuracy: 0.9045 - val_loss: 0.2317 - val_accuracy: 0.9041
#
# Epoch 00037: val_loss did not improve from 0.22468
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 38/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2312 - accuracy: 0.9045 - val_loss: 0.2317 - val_accuracy: 0.9041
#
# Epoch 00038: val_loss did not improve from 0.22468
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 39/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2312 - accuracy: 0.9045 - val_loss: 0.2317 - val_accuracy: 0.9041
#
# Epoch 00039: val_loss did not improve from 0.22468
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# Epoch 40/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.2312 - accuracy: 0.9045 - val_loss: 0.2317 - val_accuracy: 0.9041
#
# Epoch 00040: val_loss did not improve from 0.22468
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# Epoch 41/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.2312 - accuracy: 0.9045 - val_loss: 0.2317 - val_accuracy: 0.9041
# Restoring model weights from the end of the best epoch.
#
# Epoch 00041: val_loss did not improve from 0.22468
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 9.536743617033494e-10.
# Epoch 00041: early stopping
# 1446/1446 [==============================] - 4s 3ms/step - loss: 0.2320 - accuracy: 0.9044
# Epoch 1/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.4291 - accuracy: 0.8075 - val_loss: 0.3340 - val_accuracy: 0.8706
#
# Epoch 00001: val_loss did not improve from 0.22468
# Epoch 2/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.3263 - accuracy: 0.8737 - val_loss: 0.3296 - val_accuracy: 0.8701
#
# Epoch 00002: val_loss did not improve from 0.22468
# Epoch 3/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.3219 - accuracy: 0.8763 - val_loss: 0.3239 - val_accuracy: 0.8734
#
# Epoch 00003: val_loss did not improve from 0.22468
# Epoch 4/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.3205 - accuracy: 0.8778 - val_loss: 0.3225 - val_accuracy: 0.8763
#
# Epoch 00004: val_loss did not improve from 0.22468
# Epoch 5/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.3196 - accuracy: 0.8791 - val_loss: 0.3212 - val_accuracy: 0.8809
#
# Epoch 00005: val_loss did not improve from 0.22468
# Epoch 6/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.3177 - accuracy: 0.8805 - val_loss: 0.3182 - val_accuracy: 0.8802
#
# Epoch 00006: val_loss did not improve from 0.22468
# Epoch 7/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.3142 - accuracy: 0.8827 - val_loss: 0.3141 - val_accuracy: 0.8856
#
# Epoch 00007: val_loss did not improve from 0.22468
# Epoch 8/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.3088 - accuracy: 0.8848 - val_loss: 0.3076 - val_accuracy: 0.8825
#
# Epoch 00008: val_loss did not improve from 0.22468
# Epoch 9/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.3014 - accuracy: 0.8860 - val_loss: 0.2986 - val_accuracy: 0.8838
#
# Epoch 00009: val_loss did not improve from 0.22468
# Epoch 10/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.2921 - accuracy: 0.8861 - val_loss: 0.2880 - val_accuracy: 0.8853
#
# Epoch 00010: val_loss did not improve from 0.22468
# Epoch 11/100
# 5784/5784 [==============================] - 26s 5ms/step - loss: 0.2843 - accuracy: 0.8888 - val_loss: 0.2823 - val_accuracy: 0.8896
#
# Epoch 00011: val_loss did not improve from 0.22468
# Epoch 12/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2801 - accuracy: 0.8914 - val_loss: 0.2789 - val_accuracy: 0.8906
#
# Epoch 00012: val_loss did not improve from 0.22468
# Epoch 13/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.2765 - accuracy: 0.8927 - val_loss: 0.2747 - val_accuracy: 0.8917
#
# Epoch 00013: val_loss did not improve from 0.22468
# Epoch 14/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2698 - accuracy: 0.8930 - val_loss: 0.2654 - val_accuracy: 0.8919
#
# Epoch 00014: val_loss did not improve from 0.22468
# Epoch 15/100
# 5784/5784 [==============================] - 26s 4ms/step - loss: 0.2609 - accuracy: 0.8926 - val_loss: 0.2581 - val_accuracy: 0.8925
#
# Epoch 00015: val_loss did not improve from 0.22468
# Epoch 16/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2563 - accuracy: 0.8931 - val_loss: 0.2564 - val_accuracy: 0.8949
#
# Epoch 00016: val_loss did not improve from 0.22468
# Epoch 17/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2540 - accuracy: 0.8952 - val_loss: 0.2560 - val_accuracy: 0.8956
#
# Epoch 00017: val_loss did not improve from 0.22468
# Epoch 18/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2524 - accuracy: 0.8960 - val_loss: 0.2512 - val_accuracy: 0.8951
#
# Epoch 00018: val_loss did not improve from 0.22468
# Epoch 19/100
# 5784/5784 [==============================] - 31s 5ms/step - loss: 0.2511 - accuracy: 0.8964 - val_loss: 0.2509 - val_accuracy: 0.8965
#
# Epoch 00019: val_loss did not improve from 0.22468
# Epoch 20/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2499 - accuracy: 0.8969 - val_loss: 0.2488 - val_accuracy: 0.8962
#
# Epoch 00020: val_loss did not improve from 0.22468
# Epoch 21/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2487 - accuracy: 0.8971 - val_loss: 0.2517 - val_accuracy: 0.8968
#
# Epoch 00021: val_loss did not improve from 0.22468
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 22/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2474 - accuracy: 0.8973 - val_loss: 0.2480 - val_accuracy: 0.8972
#
# Epoch 00022: val_loss did not improve from 0.22468
# Epoch 23/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.2469 - accuracy: 0.8978 - val_loss: 0.2471 - val_accuracy: 0.8973
#
# Epoch 00023: val_loss did not improve from 0.22468
# Epoch 24/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2465 - accuracy: 0.8978 - val_loss: 0.2470 - val_accuracy: 0.8971
#
# Epoch 00024: val_loss did not improve from 0.22468
# Epoch 25/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2461 - accuracy: 0.8980 - val_loss: 0.2460 - val_accuracy: 0.8973
#
# Epoch 00025: val_loss did not improve from 0.22468
# Epoch 26/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2457 - accuracy: 0.8981 - val_loss: 0.2456 - val_accuracy: 0.8974
#
# Epoch 00026: val_loss did not improve from 0.22468
# Epoch 27/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.2453 - accuracy: 0.8983 - val_loss: 0.2455 - val_accuracy: 0.8975
#
# Epoch 00027: val_loss did not improve from 0.22468
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 28/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.2447 - accuracy: 0.8984 - val_loss: 0.2451 - val_accuracy: 0.8975
#
# Epoch 00028: val_loss did not improve from 0.22468
# Epoch 29/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2444 - accuracy: 0.8985 - val_loss: 0.2448 - val_accuracy: 0.8975
#
# Epoch 00029: val_loss did not improve from 0.22468
# Epoch 30/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2443 - accuracy: 0.8986 - val_loss: 0.2449 - val_accuracy: 0.8978
#
# Epoch 00030: val_loss did not improve from 0.22468
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 31/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2440 - accuracy: 0.8987 - val_loss: 0.2445 - val_accuracy: 0.8977
#
# Epoch 00031: val_loss did not improve from 0.22468
# Epoch 32/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.2439 - accuracy: 0.8989 - val_loss: 0.2448 - val_accuracy: 0.8975
#
# Epoch 00032: val_loss did not improve from 0.22468
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 33/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.2437 - accuracy: 0.8989 - val_loss: 0.2443 - val_accuracy: 0.8979
#
# Epoch 00033: val_loss did not improve from 0.22468
# Epoch 34/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.2437 - accuracy: 0.8988 - val_loss: 0.2442 - val_accuracy: 0.8981
#
# Epoch 00034: val_loss did not improve from 0.22468
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 35/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2436 - accuracy: 0.8989 - val_loss: 0.2441 - val_accuracy: 0.8980
#
# Epoch 00035: val_loss did not improve from 0.22468
# Epoch 36/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2436 - accuracy: 0.8989 - val_loss: 0.2441 - val_accuracy: 0.8980
#
# Epoch 00036: val_loss did not improve from 0.22468
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 37/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.2435 - accuracy: 0.8989 - val_loss: 0.2441 - val_accuracy: 0.8981
#
# Epoch 00037: val_loss did not improve from 0.22468
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 38/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.2435 - accuracy: 0.8989 - val_loss: 0.2441 - val_accuracy: 0.8980
#
# Epoch 00038: val_loss did not improve from 0.22468
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 39/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.2435 - accuracy: 0.8989 - val_loss: 0.2441 - val_accuracy: 0.8980
#
# Epoch 00039: val_loss did not improve from 0.22468
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 40/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.2435 - accuracy: 0.8989 - val_loss: 0.2441 - val_accuracy: 0.8982
#
# Epoch 00040: val_loss did not improve from 0.22468
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 41/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2435 - accuracy: 0.8989 - val_loss: 0.2441 - val_accuracy: 0.8981
#
# Epoch 00041: val_loss did not improve from 0.22468
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 42/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.2435 - accuracy: 0.8989 - val_loss: 0.2441 - val_accuracy: 0.8981
#
# Epoch 00042: val_loss did not improve from 0.22468
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 43/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2435 - accuracy: 0.8989 - val_loss: 0.2441 - val_accuracy: 0.8981
#
# Epoch 00043: val_loss did not improve from 0.22468
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 44/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.2435 - accuracy: 0.8989 - val_loss: 0.2441 - val_accuracy: 0.8981
#
# Epoch 00044: val_loss did not improve from 0.22468
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 45/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2435 - accuracy: 0.8989 - val_loss: 0.2441 - val_accuracy: 0.8981
#
# Epoch 00045: val_loss did not improve from 0.22468
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 46/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2435 - accuracy: 0.8989 - val_loss: 0.2441 - val_accuracy: 0.8981
#
# Epoch 00046: val_loss did not improve from 0.22468
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 47/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2435 - accuracy: 0.8989 - val_loss: 0.2441 - val_accuracy: 0.8981
#
# Epoch 00047: val_loss did not improve from 0.22468
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 48/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.2435 - accuracy: 0.8989 - val_loss: 0.2441 - val_accuracy: 0.8981
#
# Epoch 00048: val_loss did not improve from 0.22468
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# Epoch 49/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2435 - accuracy: 0.8989 - val_loss: 0.2441 - val_accuracy: 0.8981
#
# Epoch 00049: val_loss did not improve from 0.22468
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# Epoch 50/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.2435 - accuracy: 0.8989 - val_loss: 0.2441 - val_accuracy: 0.8981
# Restoring model weights from the end of the best epoch.
#
# Epoch 00050: val_loss did not improve from 0.22468
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 9.536743617033494e-10.
# Epoch 00050: early stopping
# 1446/1446 [==============================] - 4s 3ms/step - loss: 0.2455 - accuracy: 0.8985
# Epoch 1/100
# 5784/5784 [==============================] - 30s 5ms/step - loss: 0.4410 - accuracy: 0.8018 - val_loss: 0.3406 - val_accuracy: 0.8609
#
# Epoch 00001: val_loss did not improve from 0.22468
# Epoch 2/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.3322 - accuracy: 0.8701 - val_loss: 0.3311 - val_accuracy: 0.8695
#
# Epoch 00002: val_loss did not improve from 0.22468
# Epoch 3/100
# 5784/5784 [==============================] - 30s 5ms/step - loss: 0.3254 - accuracy: 0.8738 - val_loss: 0.3250 - val_accuracy: 0.8732
#
# Epoch 00003: val_loss did not improve from 0.22468
# Epoch 4/100
# 5784/5784 [==============================] - 27s 5ms/step - loss: 0.3215 - accuracy: 0.8756 - val_loss: 0.3233 - val_accuracy: 0.8800
#
# Epoch 00004: val_loss did not improve from 0.22468
# Epoch 5/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.3187 - accuracy: 0.8779 - val_loss: 0.3190 - val_accuracy: 0.8785
#
# Epoch 00005: val_loss did not improve from 0.22468
# Epoch 6/100
# 5784/5784 [==============================] - 30s 5ms/step - loss: 0.3158 - accuracy: 0.8798 - val_loss: 0.3156 - val_accuracy: 0.8807
#
# Epoch 00006: val_loss did not improve from 0.22468
# Epoch 7/100
# 5784/5784 [==============================] - 30s 5ms/step - loss: 0.3121 - accuracy: 0.8821 - val_loss: 0.3108 - val_accuracy: 0.8838
#
# Epoch 00007: val_loss did not improve from 0.22468
# Epoch 8/100
# 5784/5784 [==============================] - 30s 5ms/step - loss: 0.3071 - accuracy: 0.8848 - val_loss: 0.3061 - val_accuracy: 0.8877
#
# Epoch 00008: val_loss did not improve from 0.22468
# Epoch 9/100
# 5784/5784 [==============================] - 30s 5ms/step - loss: 0.2996 - accuracy: 0.8868 - val_loss: 0.2936 - val_accuracy: 0.8887
#
# Epoch 00009: val_loss did not improve from 0.22468
# Epoch 10/100
# 5784/5784 [==============================] - 29s 5ms/step - loss: 0.2867 - accuracy: 0.8885 - val_loss: 0.2813 - val_accuracy: 0.8835
#
# Epoch 00010: val_loss did not improve from 0.22468
# Epoch 11/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2749 - accuracy: 0.8883 - val_loss: 0.2702 - val_accuracy: 0.8849
#
# Epoch 00011: val_loss did not improve from 0.22468
# Epoch 12/100
# 5784/5784 [==============================] - 28s 5ms/step - loss: 0.2683 - accuracy: 0.8893 - val_loss: 0.2659 - val_accuracy: 0.8918
#
# Epoch 00012: val_loss did not improve from 0.22468
# Epoch 13/100
# ...
# Epoch 31/100
# 5784/5784 [==============================] - 32s 5ms/step - loss: 0.2349 - accuracy: 0.9073 - val_loss: 0.2355 - val_accuracy: 0.9073
#
# Epoch 00031: val_loss did not improve from 0.22468
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 32/100
# 5784/5784 [==============================] - 31s 5ms/step - loss: 0.2347 - accuracy: 0.9075 - val_loss: 0.2355 - val_accuracy: 0.9053
#
# Epoch 00032: val_loss did not improve from 0.22468
# Epoch 33/100
# 5784/5784 [==============================] - 33s 6ms/step - loss: 0.2346 - accuracy: 0.9074 - val_loss: 0.2354 - val_accuracy: 0.9072
#
# Epoch 00033: val_loss did not improve from 0.22468
# Epoch 34/100
# 5784/5784 [==============================] - 32s 6ms/step - loss: 0.2346 - accuracy: 0.9076 - val_loss: 0.2355 - val_accuracy: 0.9083
#
# Epoch 00034: val_loss did not improve from 0.22468
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 35/100
# 5784/5784 [==============================] - 31s 5ms/step - loss: 0.2345 - accuracy: 0.9077 - val_loss: 0.2353 - val_accuracy: 0.9061
#
# Epoch 00035: val_loss did not improve from 0.22468
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 36/100
# 5784/5784 [==============================] - 33s 6ms/step - loss: 0.2345 - accuracy: 0.9078 - val_loss: 0.2352 - val_accuracy: 0.9070
#
# Epoch 00036: val_loss did not improve from 0.22468
# Epoch 37/100
# 5784/5784 [==============================] - 30s 5ms/step - loss: 0.2344 - accuracy: 0.9078 - val_loss: 0.2352 - val_accuracy: 0.9070
#
# Epoch 00037: val_loss did not improve from 0.22468
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 38/100
# 5784/5784 [==============================] - 30s 5ms/step - loss: 0.2344 - accuracy: 0.9078 - val_loss: 0.2352 - val_accuracy: 0.9070
#
# Epoch 00038: val_loss did not improve from 0.22468
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 39/100
# 5784/5784 [==============================] - 32s 5ms/step - loss: 0.2344 - accuracy: 0.9078 - val_loss: 0.2352 - val_accuracy: 0.9070
#
# Epoch 00039: val_loss did not improve from 0.22468
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 40/100
# 5784/5784 [==============================] - 30s 5ms/step - loss: 0.2344 - accuracy: 0.9079 - val_loss: 0.2352 - val_accuracy: 0.9070
#
# Epoch 00040: val_loss did not improve from 0.22468
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 41/100
# 5784/5784 [==============================] - 32s 6ms/step - loss: 0.2344 - accuracy: 0.9079 - val_loss: 0.2352 - val_accuracy: 0.9071
#
# Epoch 00041: val_loss did not improve from 0.22468
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 42/100
# 5784/5784 [==============================] - 32s 6ms/step - loss: 0.2344 - accuracy: 0.9080 - val_loss: 0.2352 - val_accuracy: 0.9072
#
# Epoch 00042: val_loss did not improve from 0.22468
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 43/100
# 5784/5784 [==============================] - 30s 5ms/step - loss: 0.2344 - accuracy: 0.9080 - val_loss: 0.2352 - val_accuracy: 0.9072
# Restoring model weights from the end of the best epoch.
#
# Epoch 00043: val_loss did not improve from 0.22468
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 00043: early stopping
# 1446/1446 [==============================] - 5s 3ms/step - loss: 0.2351 - accuracy: 0.9079
# Epoch 1/100
# 5784/5784 [==============================] - 33s 6ms/step - loss: 0.4250 - accuracy: 0.8118 - val_loss: 0.3338 - val_accuracy: 0.8700
#
# Epoch 00001: val_loss did not improve from 0.22468
# Epoch 2/100
# 5784/5784 [==============================] - 30s 5ms/step - loss: 0.3264 - accuracy: 0.8737 - val_loss: 0.3257 - val_accuracy: 0.8763
#
# Epoch 00002: val_loss did not improve from 0.22468
# Epoch 3/100
# 5784/5784 [==============================] - 30s 5ms/step - loss: 0.3218 - accuracy: 0.8765 - val_loss: 0.3228 - val_accuracy: 0.8762
#
# Epoch 00003: val_loss did not improve from 0.22468
# Epoch 4/100
# 5784/5784 [==============================] - 30s 5ms/step - loss: 0.3187 - accuracy: 0.8775 - val_loss: 0.3180 - val_accuracy: 0.8734
#
# Epoch 00004: val_loss did not improve from 0.22468
# Epoch 5/100
# 5784/5784 [==============================] - 30s 5ms/step - loss: 0.3079 - accuracy: 0.8745 - val_loss: 0.3025 - val_accuracy: 0.8709
#
# Epoch 00005: val_loss did not improve from 0.22468
# Epoch 6/100
# 5784/5784 [==============================] - 32s 6ms/step - loss: 0.2902 - accuracy: 0.8782 - val_loss: 0.2813 - val_accuracy: 0.8866
#
# Epoch 00006: val_loss did not improve from 0.22468
# Epoch 7/100
# 5784/5784 [==============================] - 32s 5ms/step - loss: 0.2722 - accuracy: 0.8912 - val_loss: 0.2662 - val_accuracy: 0.8928
#
# Epoch 00007: val_loss did not improve from 0.22468
# Epoch 8/100
# 5784/5784 [==============================] - 32s 5ms/step - loss: 0.2626 - accuracy: 0.8950 - val_loss: 0.2610 - val_accuracy: 0.8944
#
# Epoch 00008: val_loss did not improve from 0.22468
# Epoch 9/100
# 5784/5784 [==============================] - 32s 5ms/step - loss: 0.2585 - accuracy: 0.8960 - val_loss: 0.2574 - val_accuracy: 0.8952
#
# Epoch 00009: val_loss did not improve from 0.22468
# Epoch 10/100
# 5784/5784 [==============================] - 33s 6ms/step - loss: 0.2554 - accuracy: 0.8966 - val_loss: 0.2542 - val_accuracy: 0.8958
#
# Epoch 00010: val_loss did not improve from 0.22468
# Epoch 11/100
# 5784/5784 [==============================] - 30s 5ms/step - loss: 0.2524 - accuracy: 0.8972 - val_loss: 0.2510 - val_accuracy: 0.8969
#
# Epoch 00011: val_loss did not improve from 0.22468
# Epoch 12/100
# 5784/5784 [==============================] - 31s 5ms/step - loss: 0.2493 - accuracy: 0.8978 - val_loss: 0.2479 - val_accuracy: 0.8974
#
# Epoch 00012: val_loss did not improve from 0.22468
# Epoch 13/100
# 5784/5784 [==============================] - 32s 6ms/step - loss: 0.2465 - accuracy: 0.8984 - val_loss: 0.2462 - val_accuracy: 0.8978
#
# Epoch 00013: val_loss did not improve from 0.22468
# Epoch 14/100
# 5784/5784 [==============================] - 30s 5ms/step - loss: 0.2439 - accuracy: 0.8987 - val_loss: 0.2426 - val_accuracy: 0.8984
#
# Epoch 00014: val_loss did not improve from 0.22468
# Epoch 15/100
# 5784/5784 [==============================] - 30s 5ms/step - loss: 0.2417 - accuracy: 0.8993 - val_loss: 0.2402 - val_accuracy: 0.8989
#
# Epoch 00015: val_loss did not improve from 0.22468
# Epoch 16/100
# 5784/5784 [==============================] - 32s 6ms/step - loss: 0.2396 - accuracy: 0.8999 - val_loss: 0.2391 - val_accuracy: 0.8992
#
# Epoch 00016: val_loss did not improve from 0.22468
# Epoch 17/100
# 5784/5784 [==============================] - 32s 6ms/step - loss: 0.2378 - accuracy: 0.9006 - val_loss: 0.2364 - val_accuracy: 0.9002
#
# Epoch 00017: val_loss did not improve from 0.22468
# Epoch 18/100
# 5784/5784 [==============================] - 31s 5ms/step - loss: 0.2362 - accuracy: 0.9010 - val_loss: 0.2351 - val_accuracy: 0.9006
#
# Epoch 00018: val_loss did not improve from 0.22468
# Epoch 19/100
# 5784/5784 [==============================] - 32s 6ms/step - loss: 0.2348 - accuracy: 0.9015 - val_loss: 0.2339 - val_accuracy: 0.9006
#
# Epoch 00019: val_loss did not improve from 0.22468
# Epoch 20/100
# 5784/5784 [==============================] - 31s 5ms/step - loss: 0.2335 - accuracy: 0.9019 - val_loss: 0.2328 - val_accuracy: 0.9010
#
# Epoch 00020: val_loss did not improve from 0.22468
# Epoch 21/100
# 5784/5784 [==============================] - 33s 6ms/step - loss: 0.2323 - accuracy: 0.9020 - val_loss: 0.2316 - val_accuracy: 0.9019
#
# Epoch 00021: val_loss did not improve from 0.22468
# Epoch 22/100
# 5784/5784 [==============================] - 33s 6ms/step - loss: 0.2314 - accuracy: 0.9024 - val_loss: 0.2306 - val_accuracy: 0.9019
#
# Epoch 00022: val_loss did not improve from 0.22468
# Epoch 23/100
# 5784/5784 [==============================] - 33s 6ms/step - loss: 0.2305 - accuracy: 0.9026 - val_loss: 0.2328 - val_accuracy: 0.9019
#
# Epoch 00023: val_loss did not improve from 0.22468
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 24/100
# 5784/5784 [==============================] - 31s 5ms/step - loss: 0.2292 - accuracy: 0.9029 - val_loss: 0.2292 - val_accuracy: 0.9020
#
# Epoch 00024: val_loss did not improve from 0.22468
# Epoch 25/100
# 5784/5784 [==============================] - 31s 5ms/step - loss: 0.2287 - accuracy: 0.9030 - val_loss: 0.2286 - val_accuracy: 0.9022
#
# Epoch 00025: val_loss did not improve from 0.22468
# Epoch 26/100
# 5784/5784 [==============================] - 31s 5ms/step - loss: 0.2283 - accuracy: 0.9031 - val_loss: 0.2288 - val_accuracy: 0.9021
#
# Epoch 00026: val_loss did not improve from 0.22468
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 27/100
# 5784/5784 [==============================] - 32s 6ms/step - loss: 0.2277 - accuracy: 0.9031 - val_loss: 0.2281 - val_accuracy: 0.9022
#
# Epoch 00027: val_loss did not improve from 0.22468
# Epoch 28/100
# 5784/5784 [==============================] - 32s 5ms/step - loss: 0.2274 - accuracy: 0.9033 - val_loss: 0.2277 - val_accuracy: 0.9024
#
# Epoch 00028: val_loss did not improve from 0.22468
# Epoch 29/100
# 5784/5784 [==============================] - 32s 6ms/step - loss: 0.2272 - accuracy: 0.9032 - val_loss: 0.2276 - val_accuracy: 0.9021
#
# Epoch 00029: val_loss did not improve from 0.22468
# Epoch 30/100
# 5784/5784 [==============================] - 32s 6ms/step - loss: 0.2270 - accuracy: 0.9032 - val_loss: 0.2275 - val_accuracy: 0.9021
#
# Epoch 00030: val_loss did not improve from 0.22468
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 31/100
# 5784/5784 [==============================] - 31s 5ms/step - loss: 0.2266 - accuracy: 0.9033 - val_loss: 0.2271 - val_accuracy: 0.9022
#
# Epoch 00031: val_loss did not improve from 0.22468
# Epoch 32/100
# 5784/5784 [==============================] - 31s 5ms/step - loss: 0.2265 - accuracy: 0.9033 - val_loss: 0.2270 - val_accuracy: 0.9023
#
# Epoch 00032: val_loss did not improve from 0.22468
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 33/100
# 5784/5784 [==============================] - 31s 5ms/step - loss: 0.2263 - accuracy: 0.9034 - val_loss: 0.2270 - val_accuracy: 0.9024
#
# Epoch 00033: val_loss did not improve from 0.22468
# Epoch 34/100
# 5784/5784 [==============================] - 32s 6ms/step - loss: 0.2263 - accuracy: 0.9035 - val_loss: 0.2271 - val_accuracy: 0.9021
#
# Epoch 00034: val_loss did not improve from 0.22468
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 35/100
# 5784/5784 [==============================] - 30s 5ms/step - loss: 0.2262 - accuracy: 0.9034 - val_loss: 0.2268 - val_accuracy: 0.9021
#
# Epoch 00035: val_loss did not improve from 0.22468
# Epoch 36/100
# 5784/5784 [==============================] - 33s 6ms/step - loss: 0.2261 - accuracy: 0.9034 - val_loss: 0.2268 - val_accuracy: 0.9023
#
# Epoch 00036: val_loss did not improve from 0.22468
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 37/100
# 5784/5784 [==============================] - 33s 6ms/step - loss: 0.2261 - accuracy: 0.9033 - val_loss: 0.2268 - val_accuracy: 0.9021
#
# Epoch 00037: val_loss did not improve from 0.22468
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 38/100
# 5784/5784 [==============================] - 32s 5ms/step - loss: 0.2261 - accuracy: 0.9034 - val_loss: 0.2268 - val_accuracy: 0.9021
#
# Epoch 00038: val_loss did not improve from 0.22468
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 39/100
# 5784/5784 [==============================] - 34s 6ms/step - loss: 0.2261 - accuracy: 0.9034 - val_loss: 0.2268 - val_accuracy: 0.9021
#
# Epoch 00039: val_loss did not improve from 0.22468
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 40/100
# 5784/5784 [==============================] - 34s 6ms/step - loss: 0.2261 - accuracy: 0.9034 - val_loss: 0.2268 - val_accuracy: 0.9021
#
# Epoch 00040: val_loss did not improve from 0.22468
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 41/100
# 5784/5784 [==============================] - 31s 5ms/step - loss: 0.2261 - accuracy: 0.9033 - val_loss: 0.2268 - val_accuracy: 0.9023
#
# Epoch 00041: val_loss did not improve from 0.22468
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 42/100
# 5784/5784 [==============================] - 32s 5ms/step - loss: 0.2261 - accuracy: 0.9034 - val_loss: 0.2268 - val_accuracy: 0.9021
#
# Epoch 00042: val_loss did not improve from 0.22468
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 43/100
# 5784/5784 [==============================] - 33s 6ms/step - loss: 0.2261 - accuracy: 0.9034 - val_loss: 0.2268 - val_accuracy: 0.9023
#
# Epoch 00043: val_loss did not improve from 0.22468
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 44/100
# 5784/5784 [==============================] - 34s 6ms/step - loss: 0.2261 - accuracy: 0.9034 - val_loss: 0.2268 - val_accuracy: 0.9023
#
# Epoch 00044: val_loss did not improve from 0.22468
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 45/100
# 5784/5784 [==============================] - 33s 6ms/step - loss: 0.2261 - accuracy: 0.9034 - val_loss: 0.2268 - val_accuracy: 0.9023
# Restoring model weights from the end of the best epoch.
#
# Epoch 00045: val_loss did not improve from 0.22468
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 00045: early stopping
# 1446/1446 [==============================] - 5s 3ms/step - loss: 0.2267 - accuracy: 0.9032
# Epoch 1/100
# 5784/5784 [==============================] - 32s 5ms/step - loss: 0.4267 - accuracy: 0.8099 - val_loss: 0.3323 - val_accuracy: 0.8689
#
# Epoch 00001: val_loss did not improve from 0.22468
# Epoch 2/100
# 5784/5784 [==============================] - 31s 5ms/step - loss: 0.3237 - accuracy: 0.8750 - val_loss: 0.3212 - val_accuracy: 0.8753
#
# Epoch 00002: val_loss did not improve from 0.22468
# Epoch 3/100
# 5784/5784 [==============================] - 33s 6ms/step - loss: 0.3151 - accuracy: 0.8796 - val_loss: 0.3135 - val_accuracy: 0.8808
#
# Epoch 00003: val_loss did not improve from 0.22468
# Epoch 4/100
# 5784/5784 [==============================] - 33s 6ms/step - loss: 0.3086 - accuracy: 0.8829 - val_loss: 0.3081 - val_accuracy: 0.8819
#
# Epoch 00004: val_loss did not improve from 0.22468
# Epoch 5/100
# 5784/5784 [==============================] - 31s 5ms/step - loss: 0.3021 - accuracy: 0.8833 - val_loss: 0.2983 - val_accuracy: 0.8810
#
# Epoch 00005: val_loss did not improve from 0.22468
# Epoch 6/100
# 5784/5784 [==============================] - 32s 6ms/step - loss: 0.2903 - accuracy: 0.8850 - val_loss: 0.2846 - val_accuracy: 0.8855
#
# Epoch 00006: val_loss did not improve from 0.22468
# Epoch 7/100
# 5784/5784 [==============================] - 32s 5ms/step - loss: 0.2758 - accuracy: 0.8893 - val_loss: 0.2677 - val_accuracy: 0.8895
#
# Epoch 00007: val_loss did not improve from 0.22468
# Epoch 8/100
# 5784/5784 [==============================] - 32s 6ms/step - loss: 0.2625 - accuracy: 0.8932 - val_loss: 0.2585 - val_accuracy: 0.8939
#
# Epoch 00008: val_loss did not improve from 0.22468
# Epoch 9/100
# 5784/5784 [==============================] - 30s 5ms/step - loss: 0.2555 - accuracy: 0.8971 - val_loss: 0.2529 - val_accuracy: 0.8977
#
# Epoch 00009: val_loss did not improve from 0.22468
# Epoch 10/100
# 5784/5784 [==============================] - 31s 5ms/step - loss: 0.2502 - accuracy: 0.8993 - val_loss: 0.2484 - val_accuracy: 0.8987
#
# Epoch 00010: val_loss did not improve from 0.22468
# Epoch 11/100
# 2066/5784 [=========>....................] - ETA: 18s - loss: 0.2490 - accuracy: 0.8992
